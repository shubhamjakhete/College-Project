# %%
import pandas as pd #data analysis
import numpy as np #numerical python linear algebra
import csv 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mem_train = pd.read_csv('mem_size_train.csv')
mem_trainfrom sklearn.linear_model import LogisticRegression
# Out:
#      RESOURCE  Mem_Size
# 0       39353         1
# 1       17183         2
# 2       36724         3
# 3       36135         4
# 4       42680         5
# ..        ...       ...
# 574     17226       575
# 575     75078       576
# 576     25993       577
# 577     34950       578
# 578     30570       579
#
# [579 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True, normalize=False, copy_X=True, n_jobs=None)

# %%
x = mem_train.iloc[:,1:]
x
# Out:
#      Mem_Size
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
# ..        ...
# 574       575
# 575       576
# 576       577
# 577       578
# 578       579
#
# [579 rows x 1 columns]

# %%
y = mem_train.iloc[:,:-1]
y
# Out:
#      RESOURCE
# 0       39353
# 1       17183
# 2       36724
# 3       36135
# 4       42680
# ..        ...
# 574     17226
# 575     75078
# 576     25993
# 577     34950
# 578     30570
#
# [579 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.Line2D(xdata=x,ydata=y)
plt.xlabel('Memory size')
plt.ylabel('Resources')
plt.plot(x,y)
plt.show()
